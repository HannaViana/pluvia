# %% [markdown]
# # Convert neighborhoods to shapefile

# %%
! pip install tabulate
# Out:
# Collecting tabulate
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Installing collected packages: tabulate
# Successfully installed tabulate-0.9.0
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
input_data_directory = '../../../../../data/meteorologia/raw'
output_data_directory = '../../../../../data/meteorologia/clean'

dataset = 'dados_mestres'
table_name = 'bairro'

import os
import pandas as pd
import geopandas as gpd
from shapely import wkt

df = pd.read_csv(f"{input_data_directory}/{dataset}/{table_name}.csv")

# Suppose df is your original DataFrame with a column "geometry_wkt"
df['geometry'] = df['geometry_wkt'].apply(wkt.loads)

print('Original Dataframe:')
display(df.head())

# Create a GeoDataFrame; here we assume your CRS is WGS84 (EPSG:4326)
gdf = gpd.GeoDataFrame(df, geometry='geometry', crs="EPSG:4326")

# Write to shapefile
os.makedirs(f'{output_data_directory}/{dataset}', exist_ok=True)
gdf.to_file(f"{output_data_directory}/{dataset}/{table_name}.shp")
# Out:
# Original Dataframe:
#    id_bairro          nome  id_area_planejamento  id_regiao_planejamento  \
# 0          1         Saúde                     1                     1.1
# 1          4          Caju                     1                     1.1
# 2          3  Santo Cristo                     1                     1.1
# 3          2        Gamboa                     1                     1.1
# 4        161          Lapa                     1                     1.1
#
#   nome_regiao_planejamento  id_regiao_administrativa  \
# 0                   Centro                         1
# 1                   Centro                         1
# 2                   Centro                         1
# 3                   Centro                         1
# 4                   Centro                         2
#
#   nome_regiao_administrativa          area     perimetro  \
# 0                  Portuaria  3.638176e+05   2646.220568
# 1                  Portuaria  5.347481e+06  19800.522524
# 2                  Portuaria  1.684721e+06   6743.227885
# 3                  Portuaria  1.112903e+06   4612.833630
# 4                     Centro  2.983258e+05   3849.181818
#
#                                         geometry_wkt  \
# 0  POLYGON ((-43.181151633502964 -22.895430284304...
# 1  MULTIPOLYGON (((-43.22522241788469 -22.8746498...
# 2  POLYGON ((-43.194498082949806 -22.903378003392...
# 3  POLYGON ((-43.18791509600138 -22.8931217212322...
# 4  POLYGON ((-43.18166120770202 -22.9120798224676...
#
#                                             geometry
# 0  POLYGON ((-43.181151633502964 -22.895430284304...
# 1  MULTIPOLYGON (((-43.22522241788469 -22.8746498...
# 2  POLYGON ((-43.194498082949806 -22.903378003392...
# 3  POLYGON ((-43.18791509600138 -22.8931217212322...
# 4  POLYGON ((-43.18166120770202 -22.9120798224676...
# C:\Users\Hanna\AppData\Local\Temp\ipykernel_8748\658156407.py:25: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   gdf.to_file(f"{output_data_directory}/{dataset}/{table_name}.shp")
# C:\Users\Hanna\work\envs\jupyter\lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'id_area_planejamento' to 'id_area_pl'
#   ogr_write(
# C:\Users\Hanna\work\envs\jupyter\lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'id_regiao_planejamento' to 'id_regiao_'
#   ogr_write(
# C:\Users\Hanna\work\envs\jupyter\lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'nome_regiao_planejamento' to 'nome_regia'
#   ogr_write(
# C:\Users\Hanna\work\envs\jupyter\lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'id_regiao_administrativa' to 'id_regia_1'
#   ogr_write(
# C:\Users\Hanna\work\envs\jupyter\lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'nome_regiao_administrativa' to 'nome_reg_1'
#   ogr_write(
# C:\Users\Hanna\work\envs\jupyter\lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'geometry_wkt' to 'geometry_w'
#   ogr_write(
# C:\Users\Hanna\work\envs\jupyter\lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 'POLYGON ((-43.181151633502964 -22.89543028430424, -43.181187322066535 -22.895421933343506, -43.181319211976046 -22.895376936501126, -43.18159513339742 -22.89528283894661, -43.18385665233788 -22.894511315355047, -43.18612954812871 -22.893732757574334, -43.186752068685244 -22.895192495307914, -43.18700039166821 -22.895737421309743, -43.18717606708901 -22.896204039244466, -43.1872646225002 -22.89639089588073, -43.18779181099876 -22.897368580441274, -43.18769381875763 -22.89741523265336, -43.187251205848895 -22.89753227361073, -43.18754441620524 -22.898315846971695, -43.18758619912986 -22.89861884257254, -43.18754363512147 -22.899049288144067, -43.187533485638674 -22.899138302308607, -43.18749647316827 -22.899334291048454, -43.18744322510974 -22.899461013881712, -43.18736679318305 -22.899608780296226, -43.18729625169638 -22.899745960719866, -43.18703434809704 -22.899620881530982, -43.18663887172575 -22.899425375631463, -43.18642079811814 -22.89944934646959, -43.18440264659155 -22.899792569183308, -43.184337825557755 -22.899924487380282, -43.184267422845544 -22.900051008411314, -43.184055617788474 -22.900467868021956, -43.1834292256647 -22.900184737998412, -43.18352937004523 -22.89998423564104, -43.18339256554227 -22.899929572879454, -43.183104746751646 -22.900462325548112, -43.183039950647874 -22.900599568617096, -43.18279416774081 -22.90055964181511, -43.18239393319026 -22.900501965764867, -43.18222790822577 -22.900489500741397, -43.18213125550902 -22.900435296287466, -43.182040845646604 -22.900344049299758, -43.18189638778576 -22.900007999896715, -43.18161880522399 -22.89934145140857, -43.180781195694635 -22.897283232047606, -43.18131664962891 -22.89708229357997, -43.18153511634647 -22.89702113077574, -43.18179962447994 -22.89694983686677, -43.18137927741508 -22.895952678009646, -43.181257331848265 -22.89568298906121, -43.181151633502964 -22.89543028430424))' of field geometry_w has been truncated to 254 characters.  This warning will not be emitted any more for that layer.
#   ogr_write(
# C:\Users\Hanna\work\envs\jupyter\lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 104445147.6875 of field area of feature 156 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# C:\Users\Hanna\work\envs\jupyter\lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 125044295.35205078 of field area of feature 158 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# C:\Users\Hanna\work\envs\jupyter\lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 131786592.9921875 of field area of feature 162 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
